# %% [markdown]
# <a href="https://colab.research.google.com/github/quarantin4ik/Test/blob/main/seminar_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ##Задача 57
# 1. Прочесть с помощью pandas файл california_housing_test.csv, который находится в папке sample_data
# 2. Посмотреть сколько в нем строк и столбцов
# 3. Определить какой тип данных имеют столбцы

# %%
df = pd.read_csv("/content/sample_data/california_housing_test.csv")
df.sample(7)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 306     -122.65     38.23                52.0       1735.0           347.0
# 2914    -117.06     34.87                14.0       3348.0           619.0
# 1667    -119.12     35.33                 4.0       8574.0          1489.0
# 1829    -120.63     38.68                14.0       1821.0           316.0
# 2065    -121.91     37.47                13.0       5377.0           744.0
# 2527    -120.45     34.66                 7.0       3329.0           504.0
# 1286    -117.15     32.74                26.0       3149.0           832.0
#
#       population  households  median_income  median_house_value
# 306        712.0       343.0         3.1711            200800.0
# 2914      1756.0       557.0         3.5987             91400.0
# 1667      4250.0      1444.0         5.1036            103400.0
# 1829       769.0       266.0         3.0789            131700.0
# ...

# %%
df.shape
# Out:
# (3000, 9)

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %% [markdown]
# ## Задача №59
# 1. Проверить есть ли в файле пустые значения
# 2. Показать median_house_value где median_income < 2
# 3. Показать данные в первых 2 столбцах
# 4. Выбрать данные где housing_median_age < 20 и
# median_house_value > 70000

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
df.sample()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1653    -116.98     33.26                12.0       5898.0          1002.0
#
#       population  households  median_income  median_house_value
# 1653      3129.0       945.0         4.7647            254100.0

# %%
df[df['median_income']<2]["median_house_value"]
# Out:
# 5        67000.0
# 6        67000.0
# 16      181300.0
# 28      350000.0
# 43       79300.0
#           ...
# 2943     57200.0
# 2964     91300.0
# 2985    109400.0
# 2986     85400.0
# 2995    225000.0
# Name: median_house_value, Length: 360, dtype: float64

# %%
df[df.median_income<2].median_house_value
# Out:
# 5        67000.0
# 6        67000.0
# 16      181300.0
# 28      350000.0
# 43       79300.0
#           ...
# 2943     57200.0
# 2964     91300.0
# 2985    109400.0
# 2986     85400.0
# 2995    225000.0
# Name: median_house_value, Length: 360, dtype: float64

# %%
df.loc[df['median_income']<2,"median_house_value"]
# Out:
# 5        67000.0
# 6        67000.0
# 16      181300.0
# 28      350000.0
# 43       79300.0
#           ...
# 2943     57200.0
# 2964     91300.0
# 2985    109400.0
# 2986     85400.0
# 2995    225000.0
# Name: median_house_value, Length: 360, dtype: float64

# %%
df[['longitude',"latitude"]]
# Out:
#       longitude  latitude
# 0       -122.05     37.37
# 1       -118.30     34.26
# 2       -117.81     33.78
# 3       -118.36     33.82
# 4       -119.67     36.33
# ...         ...       ...
# 2995    -119.86     34.42
# 2996    -118.14     34.06
# 2997    -119.70     36.30
# 2998    -117.12     34.10
# 2999    -119.63     34.42
#
# [3000 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
df.columns[:2]
# Out:
# Index(['longitude', 'latitude'], dtype='object')

# %%
df[df.columns[:2]]
# Out:
#       longitude  latitude
# 0       -122.05     37.37
# 1       -118.30     34.26
# 2       -117.81     33.78
# 3       -118.36     33.82
# 4       -119.67     36.33
# ...         ...       ...
# 2995    -119.86     34.42
# 2996    -118.14     34.06
# 2997    -119.70     36.30
# 2998    -117.12     34.10
# 2999    -119.63     34.42
#
# [3000 rows x 2 columns]

# %%
df.iloc[:5,:2]
# Out:
#    longitude  latitude
# 0    -122.05     37.37
# 1    -118.30     34.26
# 2    -117.81     33.78
# 3    -118.36     33.82
# 4    -119.67     36.33

# %%
df.loc[:5,:"latitude"]
# Out:
#    longitude  latitude
# 0    -122.05     37.37
# 1    -118.30     34.26
# 2    -117.81     33.78
# 3    -118.36     33.82
# 4    -119.67     36.33
# 5    -119.56     36.51

# %%
df.loc[:5,["longitude","latitude"]]
# Out:
#    longitude  latitude
# 0    -122.05     37.37
# 1    -118.30     34.26
# 2    -117.81     33.78
# 3    -118.36     33.82
# 4    -119.67     36.33
# 5    -119.56     36.51

# %%
df[(df['housing_median_age']<20) & (df["median_house_value"]>70000)]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4       -119.67     36.33                19.0       1241.0           244.0
# 7       -120.65     35.48                19.0       2310.0           471.0
# 8       -122.84     38.40                15.0       3080.0           617.0
# 13      -117.03     32.97                16.0       3936.0           694.0
# 16      -120.81     37.53                15.0        570.0           123.0
# ...         ...       ...                 ...          ...             ...
# 2978    -121.34     38.64                17.0       2761.0           501.0
# 2981    -120.66     35.49                17.0       4422.0           945.0
# 2984    -117.59     33.88                13.0       3239.0           849.0
# 2985    -120.47     34.94                17.0       1368.0           308.0
# 2991    -117.17     34.28                13.0       4867.0           718.0
#
#       population  households  median_income  median_house_value
# ...

# %% [markdown]
# ##Задача №61
# 1. Определить какое максимальное и минимальное значение median_house_value
# 2. Показать максимальное median_house_value, где median_income = 3.1250
# 3. Узнать какая максимальная population в зоне минимального значения median_house_value

# %%
df['median_house_value'].min(),df['median_house_value'].max()
# Out:
# (22500.0, 500001.0)

# %%
df[df['median_income']==3.1250]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 207     -122.10     37.68                31.0       1892.0           428.0
# 784     -118.31     33.80                30.0       3096.0           757.0
# 904     -120.77     37.01                28.0       1689.0           378.0
# 1908    -119.19     34.22                26.0       3175.0           736.0
#
#       population  households  median_income  median_house_value
# 207       1162.0       389.0          3.125            167100.0
# 784       2048.0       704.0          3.125            233300.0
# 904       1057.0       267.0          3.125            156300.0
# 1908      2460.0       775.0          3.125            219900.0
